# %% [markdown]
# # Lung segmentation from Chest X-Ray dataset
#
# **About the data**:
# - The dataset is made up of images and segmentated mask from two diffrent sources.
# - There is a slight abnormality in naming convention of masks.
# - Some images don't have their corresponding masks.
# - Images from the Shenzhen dataset has apparently smaller lungs as compared to the Montgomery dataset.
#
#
# ## Take a look at the dataset

# %%
import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.path.join("../input/chest-x-ray-dataset/detect_lung_images_CXR_crops") # 원본이미지 800
mask_path = os.path.join("../input/chest-x-ray-dataset","maskcrop704/") # 폐 segmentation 마스크 이미지 704장

# %% [markdown]
# They can inspected the concerning dataset seperately [here](http://https://www.kaggle.com/kmader/pulmonary-chest-xray-abnormalities/home).

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path) # 800 원본이미지 파일이름 리스트
mask = os.listdir(mask_path) # 704개 마스크 이미지 파일이름 리스트
mask = [fName.split(".png")[0] for fName in mask] # .png 뺀마스크이미지 파일이름 704개 리스트
image_file_name = [fName.split("_mask")[0] for fName in mask] # 마스크 이미지에서 _mask를 뺸 이미지 파일 이름

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check)) # 파일이름에 "mask" 포함 마스크 이미지 파일 566 (이름에 mask가 없는 이미지가 있음 138장)
# Out:
# Total mask that has modified name: 566

# %% [markdown]
# Earlier I was going to train on the Shenzhen dataset while perform prediction on the Montgomery dataset. However, the nature of the data was diffrent in both the set. The images from Shenzhen dataset had smaller lung-to-image ratio as compared to the Montgomery dataset.
#
# Thus, I am loading the two dataset seperately which I combined once I got to know about the disparity.

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path)) # 파일이름에 mask 없는 이미지 파일이름만 출력 138개 (~~~.png)
training_files = check 

def getData(X_shape, flag = "test"): # 이미지 데이터 리사이즈 후에 배열로 저장
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in tqdm(testing_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0] # 원본 test138개
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0] # mask test138개
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    # 원본 이미지 파일800  _mask 붙어있는 건 
    if flag == "train":
        for i in tqdm(training_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0] # 566 원본이미지
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0] # 566 mask

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check
# 원본이미지와 마스크 이미지 비교 체크
def plotMask(X,y):
    sample = []
    
    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
# Load training and testing data # 512 * 512 로 데이터 리사이즈 
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [00:16<00:00, 34.95it/s]
# 100%|██████████| 138/138 [00:03<00:00, 40.54it/s]

# %%
X_train[0][0]
# Out:
# array([ 20,  19,  20,  21,  19,  19,  19,  19,  18,  18,  17,  17,  15,
#         16,  16,  18,  17,  18,  18,  17,  17,  16,  15,  17,  16,  17,
#         16,  15,  14,  13,  13,  12,  16,  13,  12,  10,  13,  12,  13,
#         11,  11,  11,  11,   7,   9,   9,   7,   7,   5,   8,   7,   7,
#          5,   4,   6,   9,   8,  12,  22,  27,  35,  38,  38,  45,  45,
#         47,  46,  48,  50,  55,  57,  58,  57,  57,  61,  66,  67,  69,
#         74,  79,  77,  85,  84,  86,  89,  96, 100, 100, 106, 104, 103,
#        101, 102, 104, 101, 108, 104, 110, 110, 102, 107, 107, 106, 113,
#        110, 110, 112, 115, 117, 118, 121, 122, 121, 125, 130, 132, 136,
#        137, 139, 141, 146, 147, 147, 144, 145, 148, 148, 145, 151, 152,
#        156, 156, 155, 156, 157, 160, 159, 163, 160, 158, 162, 161, 165,
#        170, 172, 180, 186, 190, 182, 181, 177, 183, 179, 179, 179, 178,
#        181, 182, 185, 184, 181, 180, 178, 180, 179, 183, 183, 184, 182,
#        183, 185, 188, 185, 184, 189, 189, 186, 186, 186, 189, 192, 193,
#        191, 192, 192, 189, 189, 192, 193, 193, 187, 189, 190, 192, 194,
#        191, 190, 193, 195, 194, 194, 196, 200, 197, 198, 204, 208, 205,
#        208, 210, 212, 215, 211, 213, 216, 215, 211, 211, 211, 211, 213,
#        212, 218, 219, 218, 214, 214, 213, 213, 208, 202, 196, 194, 193,
#        189, 184, 186, 181, 184, 194, 196, 207, 201, 197, 201, 203, 197,
#        190, 192, 189, 189, 190, 197, 202, 210, 214, 214, 211, 214, 213,
#        211, 210, 209, 208, 208, 210, 211, 209, 208, 209, 203, 205, 201,
#        201, 201, 201, 196, 197, 199, 198, 195, 194, 193, 197, 195, 193,
#        193, 190, 191, 197, 188, 191, 190, 192, 188, 189, 185, 188, 189,
#        191, 189, 191, 196, 191, 189, 188, 186, 189, 187, 192, 190, 195,
#        194, 195, 194, 195, 195, 195, 194, 194, 191, 189, 188, 187, 185,
#        185, 185, 186, 186, 184, 186, 191, 189, 188, 189, 188, 187, 181,
#        184, 177, 173, 175, 172, 173, 169, 171, 175, 175, 172, 173, 170,
#        174, 169, 165, 167, 164, 162, 158, 154, 153, 153, 147, 145, 148,
#        148, 150, 143, 144, 141, 140, 133, 137, 135, 129, 132, 138, 145,
#        140, 138, 136, 138, 140, 141, 136, 138, 136, 134, 134, 134, 131,
#        133, 131, 130, 129, 128, 124, 127, 126, 128, 132, 127, 127, 130,
#        130, 127, 128, 128, 122, 122, 126, 127, 124, 124, 123, 123, 121,
#        119, 119, 118, 118, 113, 112, 112, 116, 111, 114, 115, 112, 113,
#        111, 114, 117, 111, 112, 108, 110, 109, 105, 110, 111, 106, 105,
#        107, 108, 107, 105, 106, 105, 106, 106, 104, 108, 108, 103, 104,
#        100, 103, 102, 102,  99, 102,  98, 100,  96,  98,  96,  92,  95,
#         98,  95,  95,  99,  96,  91,  96,  95,  93,  93,  92,  89,  89,
#         93,  92,  89,  88,  91,  89,  93,  90,  90,  87,  86,  85,  85,
#         82,  87,  82,  84,  89,  83,  84,  85,  82,  85,  86,  84,  84,
#         86,  85,  87,  85,  90], dtype=uint8)

# %% [markdown]
# # Perform Sanity Check
#
# It is prudent to perform sanity check of the data correspondance. It become a routine check-up after a while but it is very crucial to check if we had made a mistake in loading the data.

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %% [markdown]
# Both the sets looks correct. Let's combine them and further use them as a unified dataset.

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %% [markdown]
# ## Define  the network and callbacks
#
# I am going to use my favourite segmentation network - U-Nets. You can read about them [here](https://arxiv.org/abs/1505.04597).

# %%
# U-net 이용
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

# flatten
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Compile and train the Unet Model

# %%
model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 1)  33          conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks, Early Stopping and Reduced LR

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %% [markdown]
# #### Train the model
#
# I intially used a 60-40 train-test spit and got a loss of -0.97. However, the better way to do it is 80-10-10 train-test-validation spit. Below I am roughly doing the later.

# %%
from IPython.display import clear_output
from keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4), 
              loss=[dice_coef_loss], 
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0, # 이미지를 -1과 1사이의 값으로 만들어준다.
                                                            (mask>127).astype(np.float32), # (mask>127) 조건을 통해서 만족하는 부분1 아니면 0으로 만들어준다.
                                                            test_size = 0.1,random_state = 2018) # 0과 1로 이루어진 이진 이미지(binary image)가 된다.

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 25,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Train on 569 samples, validate on 64 samples
# Epoch 1/25
# 569/569 [==============================] - 31s 54ms/step - loss: -0.5570 - dice_coef: 0.5570 - binary_accuracy: 0.7134 - val_loss: -0.7349 - val_dice_coef: 0.7349 - val_binary_accuracy: 0.7918
#
# Epoch 00001: val_loss improved from inf to -0.73485, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.8230 - dice_coef: 0.8230 - binary_accuracy: 0.8295 - val_loss: -0.8549 - val_dice_coef: 0.8549 - val_binary_accuracy: 0.8633
#
# Epoch 00002: val_loss improved from -0.73485 to -0.85490, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.8695 - dice_coef: 0.8695 - binary_accuracy: 0.8718 - val_loss: -0.8990 - val_dice_coef: 0.8990 - val_binary_accuracy: 0.9077
#
# Epoch 00003: val_loss improved from -0.85490 to -0.89903, saving model to cxr_reg_weights.best.hdf5
# Epoch 4/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9130 - dice_coef: 0.9130 - binary_accuracy: 0.9160 - val_loss: -0.9336 - val_dice_coef: 0.9336 - val_binary_accuracy: 0.9363
#
# Epoch 00004: val_loss improved from -0.89903 to -0.93360, saving model to cxr_reg_weights.best.hdf5
# Epoch 5/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9322 - dice_coef: 0.9322 - binary_accuracy: 0.9348 - val_loss: -0.9410 - val_dice_coef: 0.9410 - val_binary_accuracy: 0.9430
#
# Epoch 00005: val_loss improved from -0.93360 to -0.94101, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9409 - dice_coef: 0.9409 - binary_accuracy: 0.9433 - val_loss: -0.9501 - val_dice_coef: 0.9501 - val_binary_accuracy: 0.9523
#
# Epoch 00006: val_loss improved from -0.94101 to -0.95012, saving model to cxr_reg_weights.best.hdf5
# Epoch 7/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9461 - dice_coef: 0.9461 - binary_accuracy: 0.9483 - val_loss: -0.9490 - val_dice_coef: 0.9490 - val_binary_accuracy: 0.9506
#
# Epoch 00007: val_loss did not improve from -0.95012
# Epoch 8/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9488 - dice_coef: 0.9488 - binary_accuracy: 0.9508 - val_loss: -0.9549 - val_dice_coef: 0.9549 - val_binary_accuracy: 0.9565
#
# Epoch 00008: val_loss improved from -0.95012 to -0.95490, saving model to cxr_reg_weights.best.hdf5
# Epoch 9/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9514 - dice_coef: 0.9514 - binary_accuracy: 0.9533 - val_loss: -0.9550 - val_dice_coef: 0.9550 - val_binary_accuracy: 0.9565
#
# Epoch 00009: val_loss improved from -0.95490 to -0.95500, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9541 - dice_coef: 0.9541 - binary_accuracy: 0.9559 - val_loss: -0.9581 - val_dice_coef: 0.9581 - val_binary_accuracy: 0.9598
#
# Epoch 00010: val_loss improved from -0.95500 to -0.95811, saving model to cxr_reg_weights.best.hdf5
# Epoch 11/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9554 - dice_coef: 0.9554 - binary_accuracy: 0.9571 - val_loss: -0.9602 - val_dice_coef: 0.9602 - val_binary_accuracy: 0.9620
#
# Epoch 00011: val_loss improved from -0.95811 to -0.96022, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9560 - dice_coef: 0.9560 - binary_accuracy: 0.9577 - val_loss: -0.9546 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9576
#
# Epoch 00012: val_loss did not improve from -0.96022
# Epoch 13/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9566 - dice_coef: 0.9566 - binary_accuracy: 0.9583 - val_loss: -0.9600 - val_dice_coef: 0.9600 - val_binary_accuracy: 0.9621
#
# Epoch 00013: val_loss did not improve from -0.96022
# Epoch 14/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9568 - dice_coef: 0.9568 - binary_accuracy: 0.9586 - val_loss: -0.9592 - val_dice_coef: 0.9592 - val_binary_accuracy: 0.9606
#
# Epoch 00014: val_loss did not improve from -0.96022
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 15/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9603 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9626
#
# Epoch 00015: val_loss improved from -0.96022 to -0.96113, saving model to cxr_reg_weights.best.hdf5
# Epoch 16/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9616 - val_loss: -0.9643 - val_dice_coef: 0.9643 - val_binary_accuracy: 0.9660
#
# Epoch 00016: val_loss improved from -0.96113 to -0.96432, saving model to cxr_reg_weights.best.hdf5
# Epoch 17/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9607 - dice_coef: 0.9607 - binary_accuracy: 0.9623 - val_loss: -0.9635 - val_dice_coef: 0.9635 - val_binary_accuracy: 0.9653
#
# Epoch 00017: val_loss did not improve from -0.96432
# Epoch 18/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9628 - val_loss: -0.9647 - val_dice_coef: 0.9647 - val_binary_accuracy: 0.9663
#
# Epoch 00018: val_loss improved from -0.96432 to -0.96470, saving model to cxr_reg_weights.best.hdf5
# Epoch 19/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9613 - dice_coef: 0.9613 - binary_accuracy: 0.9629 - val_loss: -0.9647 - val_dice_coef: 0.9647 - val_binary_accuracy: 0.9664
#
# Epoch 00019: val_loss improved from -0.96470 to -0.96471, saving model to cxr_reg_weights.best.hdf5
# Epoch 20/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9615 - dice_coef: 0.9615 - binary_accuracy: 0.9631 - val_loss: -0.9648 - val_dice_coef: 0.9648 - val_binary_accuracy: 0.9664
#
# Epoch 00020: val_loss improved from -0.96471 to -0.96480, saving model to cxr_reg_weights.best.hdf5
# Epoch 21/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9617 - dice_coef: 0.9617 - binary_accuracy: 0.9633 - val_loss: -0.9653 - val_dice_coef: 0.9653 - val_binary_accuracy: 0.9669
#
# Epoch 00021: val_loss improved from -0.96480 to -0.96531, saving model to cxr_reg_weights.best.hdf5
# Epoch 22/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9618 - dice_coef: 0.9618 - binary_accuracy: 0.9632 - val_loss: -0.9649 - val_dice_coef: 0.9649 - val_binary_accuracy: 0.9667
#
# Epoch 00022: val_loss did not improve from -0.96531
# Epoch 23/25
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9619 - dice_coef: 0.9619 - binary_accuracy: 0.9635 - val_loss: -0.9656 - val_dice_coef: 0.9656 - val_binary_accuracy: 0.9672
#
# Epoch 00023: val_loss improved from -0.96531 to -0.96562, saving model to cxr_reg_weights.best.hdf5
# Epoch 24/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9626 - dice_coef: 0.9626 - binary_accuracy: 0.9641 - val_loss: -0.9654 - val_dice_coef: 0.9654 - val_binary_accuracy: 0.9670
#
# Epoch 00024: val_loss did not improve from -0.96562
# Epoch 25/25
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9627 - dice_coef: 0.9627 - binary_accuracy: 0.9642 - val_loss: -0.9658 - val_dice_coef: 0.9658 - val_binary_accuracy: 0.9674
#
# Epoch 00025: val_loss improved from -0.96562 to -0.96583, saving model to cxr_reg_weights.best.hdf5

# %% [markdown]
# ## Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %% [markdown]
# ## Test the model

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Pridiction")
